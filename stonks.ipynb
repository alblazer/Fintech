# %%
import os
import tarfile
import urllib
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fiserv = pd.read_csv("fiserv.csv")
fiserv.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close   Volume
# 0   7/6/2016  54.669998  54.889999  54.220001  54.355000  54.355000  2832400
# 1   7/7/2016  54.314999  54.404999  53.985001  54.215000  54.215000  1726200
# 2   7/8/2016  54.615002  54.965000  54.529999  54.845001  54.845001  2594000
# 3  7/11/2016  55.000000  55.349998  54.845001  55.150002  55.150002  1898400
# 4  7/12/2016  55.520000  55.705002  54.955002  55.095001  55.095001  1616400

# %%
#Let's check out the numerical values of the data
fiserv.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     84.022925    84.840481    83.149463    84.026852    84.026852
# std      22.314659    22.624209    21.931134    22.275960    22.275960
# min      46.615002    48.595001    46.404999    48.375000    48.375000
# 25%      63.445000    63.911249    63.253750    63.562500    63.562500
# 50%      80.689999    81.334999    79.994999    80.770001    80.770001
# 75%     104.035000   105.330002   102.765000   104.077501   104.077501
# max     126.040001   127.339996   125.870003   126.550003   126.550003
#
#              Volume
# count  1.258000e+03
# mean   3.188049e+06
# std    2.728871e+06
# min    5.321000e+05
# 25%    1.652250e+06
# 50%    2.538100e+06
# 75%    3.880525e+06
# max    4.952360e+07

# %%
#And now for some graphs
fiserv.hist(bins=50, figsize=(20, 15))
plt.show()
